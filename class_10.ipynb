# %% [markdown]
# <a href="https://colab.research.google.com/github/muntahasidd/FILE-HANDLING-IN-PYTHON/blob/main/class_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import csv
with open('Istanbul Weather Data.csv','r')as file:
   read_csv=csv.reader(file)
   for row in read_csv:
    print(row)
# Out:
# ['DateTime', 'Condition', 'Rain', 'MaxTemp', 'MinTemp', 'SunRise', 'SunSet', 'MoonRise', 'MoonSet', 'AvgWind', 'AvgHumidity', 'AvgPressure']
# ['02.09.2019', 'Partly cloudy', '0.00', '27', '22', '06:32:00', '19:37:00', '9:52:00', '21:45:00', '23', '66', '1012']
# ['01.09.2019', 'Partly cloudy', '0.00', '27', '22', '06:31:00', '19:38:00', '8:37:00', '21:13:00', '21', '66', '1011']
# ['31.08.2019', 'Patchy rain possible', '0.50', '26', '22', '06:30:00', '19:40:00', '7:21:00', '20:40:00', '22', '63', '1015']
# ['30.08.2019', 'Partly cloudy', '0.00', '27', '22', '06:29:00', '19:42:00', '6:4:00', '20:5:00', '20', '64', '1016']
# ['29.08.2019', 'Partly cloudy', '0.00', '27', '23', '06:27:00', '19:43:00', '4:47:00', '19:26:00', '24', '61', '1015']
# ['28.08.2019', 'Sunny', '0.00', '28', '24', '06:26:00', '19:44:00', '3:34:00', '18:41:00', '27', '58', '1016']
# ['27.08.2019', 'Partly cloudy', '0.00', '30', '24', '06:25:00', '19:46:00', '2:27:00', '17:50:00', '27', '61', '1016']
# ...

# %%
df=pd.read_csv('Istanbul Weather Data.csv')
df.head()
# Out:
#      DateTime             Condition  Rain  MaxTemp  MinTemp   SunRise  \
# 0  02.09.2019         Partly cloudy   0.0       27       22  06:32:00
# 1  01.09.2019         Partly cloudy   0.0       27       22  06:31:00
# 2  31.08.2019  Patchy rain possible   0.5       26       22  06:30:00
# 3  30.08.2019         Partly cloudy   0.0       27       22  06:29:00
# 4  29.08.2019         Partly cloudy   0.0       27       23  06:27:00
#
#      SunSet MoonRise   MoonSet  AvgWind  AvgHumidity  AvgPressure
# 0  19:37:00  9:52:00  21:45:00       23           66         1012
# 1  19:38:00  8:37:00  21:13:00       21           66         1011
# 2  19:40:00  7:21:00  20:40:00       22           63         1015
# 3  19:42:00   6:4:00   20:5:00       20           64         1016
# 4  19:43:00  4:47:00  19:26:00       24           61         1015

# %%
chunks=pd.read_csv('Istanbul Weather Data.csv',chunksize=10)
for chunk in chunks:
  print(chunk)
# Out:
# Streaming output truncated to the last 5000 lines.
# 1845  22:13:00  10:30:00       19           76         1010
# 1846  21:37:00   9:20:00       26           71         1012
# 1847   21:0:00    8:6:00       20           70         1012
# 1848  20:22:00   6:52:00       21           70         1013
# 1849  19:42:00   5:38:00       18           69         1014
#         DateTime                    Condition  Rain  MaxTemp  MinTemp  \
# 1850  09.08.2014                Partly cloudy  6.49       27       24
# 1851  08.08.2014                        Sunny  0.31       26       23
# 1852  07.08.2014                        Sunny  0.03       28       25
# 1853  06.08.2014                        Sunny  0.01       29       25
# 1854  05.08.2014                        Sunny  0.02       29       25
# 1855  04.08.2014                        Sunny  0.00       28       25
# 1856  03.08.2014                Partly cloudy  6.15       27       24
# ...

# %%
import pandas as pd
chunks=pd.read_csv('Istanbul Weather Data.csv', chunksize=10)
chunks.get_chunk()
# Out:
#      DateTime             Condition  Rain  MaxTemp  MinTemp   SunRise  \
# 0  02.09.2019         Partly cloudy   0.0       27       22  06:32:00
# 1  01.09.2019         Partly cloudy   0.0       27       22  06:31:00
# 2  31.08.2019  Patchy rain possible   0.5       26       22  06:30:00
# 3  30.08.2019         Partly cloudy   0.0       27       22  06:29:00
# 4  29.08.2019         Partly cloudy   0.0       27       23  06:27:00
# 5  28.08.2019                 Sunny   0.0       28       24  06:26:00
# 6  27.08.2019         Partly cloudy   0.0       30       24  06:25:00
# 7  26.08.2019                 Sunny   0.0       30       24  06:24:00
# 8  25.08.2019         Partly cloudy   0.0       30       24  06:23:00
# 9  24.08.2019         Partly cloudy   0.0       30       24  06:22:00
#
#      SunSet  MoonRise   MoonSet  AvgWind  AvgHumidity  AvgPressure
# 0  19:37:00   9:52:00  21:45:00       23           66         1012
# ...

# %%
chunks.get_chunk(10)
# Out:
#       DateTime               Condition  Rain  MaxTemp  MinTemp   SunRise  \
# 10  23.08.2019           Partly cloudy   0.0       28       24  06:21:00
# 11  22.08.2019           Partly cloudy   0.0       29       24  06:20:00
# 12  21.08.2019    Patchy rain possible   0.5       28       21  06:19:00
# 13  20.08.2019           Partly cloudy   0.0       27       22  06:18:00
# 14  19.08.2019           Partly cloudy   0.0       26       22  06:17:00
# 15  18.08.2019    Patchy rain possible   0.8       26       21  06:16:00
# 16  17.08.2019  Torrential rain shower  15.7       25       18  06:15:00
# 17  16.08.2019    Patchy rain possible   1.2       26       23  06:14:00
# 18  15.08.2019                  Cloudy   0.2       27       24  06:13:00
# 19  14.08.2019           Partly cloudy   0.0       29       24  06:12:00
#
#       SunSet  MoonRise   MoonSet  AvgWind  AvgHumidity  AvgPressure
# 10  19:52:00       NaN  13:42:00       20           74         1016
# ...

# %%
#function that access specific rows:
specific_rows=[0,10,22]
df.iloc[specific_rows]
# Out:
#       DateTime      Condition  Rain  MaxTemp  MinTemp   SunRise    SunSet  \
# 0   02.09.2019  Partly cloudy   0.0       27       22  06:32:00  19:37:00
# 10  23.08.2019  Partly cloudy   0.0       28       24  06:21:00  19:52:00
# 22  11.08.2019          Sunny   0.0       28       23  06:09:00   20:9:00
#
#     MoonRise   MoonSet  AvgWind  AvgHumidity  AvgPressure
# 0    9:52:00  21:45:00       23           66         1012
# 10       NaN  13:42:00       20           74         1016
# 22  17:31:00   2:14:00       26           63         1015

# %% [markdown]
# # **DATA** **CLEANING**

# %%
duplicate=df[df.duplicated()]
print(duplicate)
# Out:
# Empty DataFrame
# Columns: [DateTime, Condition, Rain, MaxTemp, MinTemp, SunRise, SunSet, MoonRise, MoonSet, AvgWind, AvgHumidity, AvgPressure]
# Index: []

# %%
df.shape
# Out:
# (3896, 12)

# %%
df_new=df.drop_duplicates
print(df_new)
# Out:
# <bound method DataFrame.drop_duplicates of         DateTime             Condition  Rain  MaxTemp  MinTemp   SunRise  \
# 0     02.09.2019         Partly cloudy  0.00       27       22  06:32:00
# 1     01.09.2019         Partly cloudy  0.00       27       22  06:31:00
# 2     31.08.2019  Patchy rain possible  0.50       26       22  06:30:00
# 3     30.08.2019         Partly cloudy  0.00       27       22  06:29:00
# 4     29.08.2019         Partly cloudy  0.00       27       23  06:27:00
# ...          ...                   ...   ...      ...      ...       ...
# 3891  05.01.2009              Overcast  4.32        5        3  08:29:00
# 3892  04.01.2009                  Mist  2.91        5        3  08:29:00
# 3893  03.01.2009              Overcast  0.08        5        3  08:29:00
# 3894  02.01.2009              Overcast  4.48        4        1  08:29:00
# 3895  01.01.2009         Partly cloudy  0.23        5        2  08:29:00
#
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(5,5))
mylabels=['rainy','sunny','snowy','partly cloudy']
myexplode=[0,0.1]
plt.pie(df['AvgWind'],label=mylabels,explode=myexplode,autopct='1%.1f%')
plt.title("Istanbul Weather Data")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-bec3923810d5> in <cell line: 6>()
#       4 mylabels=['rainy','sunny','snowy','partly cloudy']
#       5 myexplode=[0,0.1]
# ----> 6 plt.pie(df['AvgWind'],label=mylabels,explode=myexplode,autopct='1%.1f%')
#       7 plt.title("Istanbul Weather Data")
#       8 plt.show()
#
# TypeError: pie() got an unexpected keyword argument 'label'

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Sample DataFrame creation (replace this with your actual DataFrame)
df=pd.read_csv('Istanbul Weather Data.csv')

# Labels for each slice
mylabels = ['rainy', 'sunny', 'snowy', 'partly cloudy']

# Explode parameter to highlight slices
myexplode = [0, 0.1, 0, 0]  # Explode the second slice

# Create pie chart
plt.figure(figsize=(5,5))
plt.pie(df['AvgWind'], labels=mylabels, explode=myexplode, autopct='%1.1f%%')
plt.title("Istanbul Weather Data")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-f3fa9e75308e> in <cell line: 16>()
#      14 # Create pie chart
#      15 plt.figure(figsize=(5,5))
# ---> 16 plt.pie(df['AvgWind'], labels=mylabels, explode=myexplode, autopct='%1.1f%%')
#      17 plt.title("Istanbul Weather Data")
#      18 plt.show()
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, hatch, data)
#    2797         textprops=None, center=(0, 0), frame=False,
#    2798         rotatelabels=False, *, normalize=True, hatch=None, data=None):
# -> 2799     return gca().pie(
#    2800         x, explode=explode, labels=labels, colors=colors,
# ...

# %%
import pandas as pd
import csv
df=pd.read_csv('netflix1.csv')
df.head()
# Out:
#   show_id     type                             title         director  \
# 0      s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1      s3  TV Show                         Ganglands  Julien Leclercq
# 2      s6  TV Show                     Midnight Mass    Mike Flanagan
# 3     s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4      s8    Movie                           Sankofa     Haile Gerima
#
#          country date_added  release_year rating  duration  \
# 0  United States  9/25/2021          2020  PG-13    90 min
# 1         France  9/24/2021          2021  TV-MA  1 Season
# 2  United States  9/24/2021          2021  TV-MA  1 Season
# 3         Brazil  9/22/2021          2021  TV-PG    91 min
# 4  United States  9/24/2021          1993  TV-MA   125 min
#
#                                            listed_in
# 0                                      Documentaries
# 1  Crime TV Shows, International TV Shows, TV Act...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8790 entries, 0 to 8789
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8790 non-null   object
#  1   type          8790 non-null   object
#  2   title         8790 non-null   object
#  3   director      8790 non-null   object
#  4   country       8790 non-null   object
#  5   date_added    8790 non-null   object
#  6   release_year  8790 non-null   int64
#  7   rating        8790 non-null   object
#  8   duration      8790 non-null   object
#  9   listed_in     8790 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 686.8+ KB

# %%
df.shape
# Out:
# (8790, 10)

# %%
df.describe()
# Out:
#        release_year
# count   8790.000000
# mean    2014.183163
# std        8.825466
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
#checking null values
null_values=df.isnull().sum()
null_values
# Out:
# show_id         0
# type            0
# title           0
# director        0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# dtype: int64

# %%
if df.duplicated().values.any():
    print("There are duplicate values")
else:
    print("There are no duplicate values")
# Out:
# There are no duplicate values

# %%
#checking columns:
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in'],
#       dtype='object')

# %%
#dropping one column to again check if columns are repeated:
df.drop('show_id', inplace=True, axis=1)
df.head()
# Out:
#       type                             title         director        country  \
# 0    Movie              Dick Johnson Is Dead  Kirsten Johnson  United States
# 1  TV Show                         Ganglands  Julien Leclercq         France
# 2  TV Show                     Midnight Mass    Mike Flanagan  United States
# 3    Movie  Confessions of an Invisible Girl    Bruno Garotti         Brazil
# 4    Movie                           Sankofa     Haile Gerima  United States
#
#   date_added  release_year rating  duration  \
# 0  9/25/2021          2020  PG-13    90 min
# 1  9/24/2021          2021  TV-MA  1 Season
# 2  9/24/2021          2021  TV-MA  1 Season
# 3  9/22/2021          2021  TV-PG    91 min
# 4  9/24/2021          1993  TV-MA   125 min
#
#                                            listed_in
# 0                                      Documentaries
# 1  Crime TV Shows, International TV Shows, TV Act...
# 2                 TV Dramas, TV Horror, TV Mysteries
# ...

# %%
#visualizing data:
type_counts = df['type'].value_counts()
type_counts
# Out:
# type
# Movie      6126
# TV Show    2664
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(5,5))
mylabels = ['Movie','TVshow']
myexplode = [0, 0.1]
plt.pie(type_counts,labels = mylabels, explode = myexplode, shadow = True, autopct="%1.2f%%")
plt.title("Netflix Content Types")
plt.show()

# %%
#counting categories
import pandas as pd
import csv
df=pd.read_csv('netflix1.csv')
category_counts=df['title'].value_counts()
category_counts.head(10)
# Out:
# title
# 9-Feb                          2
# 15-Aug                         2
# 22-Jul                         2
# Dick Johnson Is Dead           1
# SGT. Will Gardner              1
# Sex and the City 2             1
# Sex and the City: The Movie    1
# Sex Doll                       1
# Sexo, Pudor y Lagrimas         1
# Shahanpan Dega Deva            1
# Name: count, dtype: int64

# %%
import matplotlib.pyplot  as plt
import seaborn as sns
category_counts = df["title"].value_counts()
top_categories = category_counts.head(10)
top_titles_df = df[df["title"].isin(top_categories.index)]

plt.figure(figsize=(12, 8))
sns.countplot(x='title', data=top_titles_df, order=top_categories.index, palette='viridis')
plt.xticks(rotation=45, ha="right")
plt.title("Top 10 Titles on Netflix")
#plt.tight_layout()
plt.show()
# Out:
# <ipython-input-11-a756b2e5e9e5>:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='title', data=top_titles_df, order=top_categories.index, palette='viridis')

# %%
country_counts = df['country'].value_counts()
country_df = pd.DataFrame({
    'country': country_counts.index,
    'count': country_counts.values
})

top_countries_df = country_df.nlargest(50, 'count')
top_countries_df
# Out:
#                  country  count
# 0          United States   3240
# 1                  India   1057
# 2         United Kingdom    638
# 3               Pakistan    421
# 4              Not Given    287
# 5                 Canada    271
# 6                  Japan    259
# 7            South Korea    214
# 8                 France    213
# 9                  Spain    182
# 10                Mexico    138
# 11                 Egypt    123
# 12             Australia    114
# 13                Turkey    112
# 14               Nigeria    105
# 15               Germany    104
# 16                 China    100
# 17                Brazil     88
# 18                Taiwan     86
# 19             Indonesia     86
# 20           Philippines     83
# 21             Hong Kong     79
# 22             Argentina     76
# 23                 Italy     66
# 24              Thailand     66
# 25              Colombia     42
# 26          South Africa     42
# 27               Denmark     30
# ...

# %%
from matplotlib import pyplot as plt
top_countries_df['count'].plot(kind='line', figsize=(8, 4), title='count')
plt.gca().spines[['top', 'right']].set_visible(False)
